# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("haberman.csv")

# %%
df
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# 5    33  60   0    1
# 6    34  59   0    2
# 7    34  66   9    2
# 8    34  58  30    1
# 9    34  60   1    1
# 10   34  61  10    1
# 11   34  67   7    1
# 12   34  60   0    1
# 13   35  64  13    1
# 14   35  63   0    1
# 15   36  60   1    1
# 16   36  69   0    1
# 17   37  60   0    1
# 18   37  63   0    1
# 19   37  58   0    1
# 20   37  59   6    1
# 21   37  60  15    1
# 22   37  63   0    1
# 23   38  69  21    2
# 24   38  59   2    1
# 25   38  60   0    1
# 26   38  60   0    1
# 27   38  62   3    1
# 28   38  64   1    1
# 29   38  66   0    1
# ..   ..  ..  ..  ...
# 275  67  66   0    1
# 276  67  61   0    1
# 277  67  65   0    1
# 278  68  67   0    1
# 279  68  68   0    1
# 280  69  67   8    2
# 281  69  60   0    1
# 282  69  65   0    1
# 283  69  66   0    1
# 284  70  58   0    2
# 285  70  58   4    2
# ...

# %%
print(df.shape)
# Out:
# (305, 4)

# %%
df['1.1'].value_counts()
# Out:
# 1    224
# 2     81
# Name: 1.1, dtype: int64

# %%
sns.set_style('whitegrid')
sns.pairplot(df,hue='1.1',height=6).map(plt.scatter,'30','1').add_legend()
plt.show()
# Out:
# C:\Users\Mohan Bishnoi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Mohan Bishnoi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9928dfa967de> in <module>
#       1 sns.set_style('whitegrid')
# ----> 2 sns.pairplot(df,hue='1.1',height=6).map(plt.scatter,'30','1').add_legend()
#       3 plt.show()
#
# TypeError: map() takes 2 positional arguments but 4 were given

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df,hue='1.1',height=4).map(sns.distplot,'30').add_legend()

plt.show();

# %%
#conclusion: Features are very difficult to extract because they are over lapping need some other way for classification
